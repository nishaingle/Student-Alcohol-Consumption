# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
from scipy import stats

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Gather Data

# %%
df1 = pd.read_csv(R"C:\Users\NEHA_NISHA\Downloads\archive (12)\student-mat.csv")
df1.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# ...

# %%
df1.shape
# Out:
# (395, 33)

# %%
df2 = pd.read_csv(R"C:\Users\NEHA_NISHA\Downloads\archive (12)\student-por.csv")
df2.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        4   0  11  11
# ...

# %%
df2.shape
# Out:
# (649, 33)

# %%
df = pd.merge(df1, df2,how='outer', on=["school","sex","age","address","famsize","Pstatus","Medu","Fedu","Mjob","Fjob","reason","nursery","internet","guardian","traveltime","studytime","famsup","activities","higher","romantic","famrel","freetime","goout","Dalc","Walc","health","schoolsup","failures","paid","absences","G1","G2","G3"])
df
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# There are 33 features in this data. What they represent is given below.
#
# school : Student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
#
# sex : Student's sex (binary: 'F' - female or 'M' - male)
#
# age : Student's age (numeric: from 15 to 22)
#
# address : Student's home address type (binary: 'U' - urban or 'R' - rural)
#
# famsize : Family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
#
# Pstatus : Parent's cohabitation status (binary: 'T' - living together or 'A' - living apart)
#
# Medu : Mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 - 5th to 9th grade, 3 - secondary education, or 4 - higher education)
#
# Fedu : Father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 - 5th to 9th grade, 3 - secondary education, or 4 - higher education)
#
# Mjob : Mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#
# Fjob : Father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#
# reason : Reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
#
# guardian : Student's guardian (nominal: 'mother', 'father' or 'other')
#
# traveltime : Home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
#
# studytime : Weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
#
# failures : Number of past class failures (numeric: n if 1<=n<3, else 4)
#
# schoolsup : Extra educational support (binary: yes or no)
#
# famsup : Family educational support (binary: yes or no)
#
# paid : Extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
#
# activities : Extra-curricular activities (binary: yes or no)
#
# nursery : Attended nursery school (binary: yes or no)
#
# higher : Wants to take higher education (binary: yes or no)
#
# internet : Internet access at home (binary: yes or no)
#
# romantic : With a romantic relationship (binary: yes or no)
#
# famrel : Quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
#
# freetime : Free time after school (numeric: from 1 - very low to 5 - very high)
#
# goout : Going out with friends (numeric: from 1 - very low to 5 - very high)
#
# Dalc : Workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# Walc : Weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# health : Current health status (numeric: from 1 - very bad to 5 - very good)
#
# absences : Number of school absences (numeric: from 0 to 93)
#
# G1 : First period grade (numeric: from 0 to 20)
#
# G2 : Second period grade (numeric: from 0 to 20)
#
# G3 : Final grade (numeric: from 0 to 20, output target)

# %%
df.shape
# Out:
# (1044, 33)

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1044 entries, 0 to 1043
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      1044 non-null   object
#  1   sex         1044 non-null   object
#  2   age         1044 non-null   int64
#  3   address     1044 non-null   object
#  4   famsize     1044 non-null   object
#  5   Pstatus     1044 non-null   object
#  6   Medu        1044 non-null   int64
#  7   Fedu        1044 non-null   int64
#  8   Mjob        1044 non-null   object
#  9   Fjob        1044 non-null   object
#  10  reason      1044 non-null   object
#  11  guardian    1044 non-null   object
#  12  traveltime  1044 non-null   int64
#  13  studytime   1044 non-null   int64
#  14  failures    1044 non-null   int64
#  15  schoolsup   1044 non-null   object
#  16  famsup      1044 non-null   object
#  17  paid        1044 non-null   object
#  18  activities  1044 non-null   object
# ...

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ### Missing Value Treatment:

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.describe()
# Out:
#                age         Medu         Fedu   traveltime    studytime  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean     16.726054     2.603448     2.387931     1.522989     1.970307
# std       1.239975     1.124907     1.099938     0.731727     0.834353
# min      15.000000     0.000000     0.000000     1.000000     1.000000
# 25%      16.000000     2.000000     1.000000     1.000000     1.000000
# 50%      17.000000     3.000000     2.000000     1.000000     2.000000
# 75%      18.000000     4.000000     3.000000     2.000000     2.000000
# max      22.000000     4.000000     4.000000     4.000000     4.000000
#
#           failures       famrel     freetime        goout         Dalc  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      0.264368     3.935824     3.201149     3.156130     1.494253
# std       0.656142     0.933401     1.031507     1.152575     0.911714
# ...

# %% [markdown]
# ###  checking and removing duplicates:

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
cat =[]
num =[]
for i in df.columns:
    if df[i].dtype==object:
        cat.append(i)
    else:
        num.append(i)

# %%
print("Categorical Features:{}".format(cat),end="\n\n")
print("Numerical Features:{}".format(num))
# Out:
# Categorical Features:['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']
#
# Numerical Features:['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3']

# %% [markdown]
# ### Delete unwanted columns:

# %%
df.drop(['school','address','famsize','Medu','Fedu','Mjob','Fjob','guardian','traveltime','nursery','higher','internet'], 
        axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1044 entries, 0 to 1043
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sex         1044 non-null   object
#  1   age         1044 non-null   int64
#  2   Pstatus     1044 non-null   object
#  3   reason      1044 non-null   object
#  4   studytime   1044 non-null   int64
#  5   failures    1044 non-null   int64
#  6   schoolsup   1044 non-null   object
#  7   famsup      1044 non-null   object
#  8   paid        1044 non-null   object
#  9   activities  1044 non-null   object
#  10  romantic    1044 non-null   object
#  11  famrel      1044 non-null   int64
#  12  freetime    1044 non-null   int64
#  13  goout       1044 non-null   int64
#  14  Dalc        1044 non-null   int64
#  15  Walc        1044 non-null   int64
#  16  health      1044 non-null   int64
#  17  absences    1044 non-null   int64
#  18  G1          1044 non-null   int64
# ...

# %%
df['age'].unique()
# Out:
# array([18, 17, 15, 16, 19, 22, 20, 21], dtype=int64)

# %%
df['reason'].unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
df['studytime'].unique()
# Out:
# array([2, 3, 1, 4], dtype=int64)

# %%
df['schoolsup'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
plt.figure(figsize=(5,5))
labels=['Female', 'Male']
plt.pie(df['sex'].value_counts().tolist()
        ,labels=['Female', 'Male'], colors=['#FFB6C1', '#7AC5CD'], 
        autopct='%1.1f%%', startangle=90)
axis = plt.axis('equal')

# %%
sns.displot(data=df, x='age', kde=False)
plt.xlabel('Student age') ## gives the x axis label
plt.ylabel('Students')
plt.title('Age of student')
# Out:
# Text(0.5, 1.0, 'Age of student')

# %%
sns.countplot(data=df, x='age', hue = 'sex')
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
sns.histplot(df['failures'], discrete=True)
plt.title('Distribution of failures')
plt.show()

# %%
plt.hist(data=df, x='studytime')
plt.xlabel('Study Time') 
plt.ylabel('Students')
plt.title('Study time of Students')
# Out:
# Text(0.5, 1.0, 'Study time of Students')

# %%
sns.countplot(data=df, x='reason')
# Out:
# <AxesSubplot:xlabel='reason', ylabel='count'>

# %%
sns.countplot(x="freetime", hue="goout", data= df)
plt.xlabel('Free Time') 
plt.ylabel('Go out')
plt.title('Students that go out on free time')
# Out:
# Text(0.5, 1.0, 'Students that go out on free time')

# %%
sns.histplot(df['absences'], bins = 40)
plt.title('Absences distribtuion')
plt.show()

# %%
f =plt.figure(figsize=(17,5))

ax=f.add_subplot(121)
sns.distplot(df[(df.romantic == 'no')]["absences"],color='coral',ax=ax)
ax.set_title('Distribution of absences for classes by single people')

ax=f.add_subplot(122)
sns.distplot(df[(df.romantic == 'yes')]['absences'],color='purple',ax=ax)
ax.set_title('Distribution of absences for classes by people in love')
# Out:
# C:\Users\NEHA_NISHA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\NEHA_NISHA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of absences for classes by people in love')

# %%
sns.displot(data=df, x='Dalc', kde=True)

# %%
sns.displot(data=df, x='Walc', kde=True)

# %%
sns.histplot(data=df, x="Dalc", hue="sex",  stat="density")
plt.title('alcohol consumption on the workdays vs gender')
plt.show()

# %%
sns.histplot(data=df, x="Walc", hue="sex",  stat="density")
plt.title('Influence of gender on the alcohol consumption on the weekend')
plt.show()

# %%
df.groupby('age')[['Dalc', 'Walc']].mean().plot(kind='bar')
plt.ylabel('Alcohol consumption')
plt.xticks(rotation=0)
plt.title('Mean alcohol consumption over age')
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.countplot(x = 'G1', data = df, palette='Blues')
plt.title('Distribution of Grade (G1)')
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.countplot(x = 'G2', data = df, palette='Blues')
plt.title('Distribution of Grade (G2)')
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.countplot(x = 'G3', data = df, palette='Blues')
plt.title('Distribution of Grade (G3)')
plt.show()

# %%
plt.figure(figsize=(4,4), dpi=100)
sns.barplot(x = 'Dalc',y = 'Walc',data = df)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
#check correlation

plt.figure(figsize= (10,8), dpi=300)
sns.heatmap(df.corr(), annot= True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data = df,x = 'G1',y = 'G2',hue ='sex')
# Out:
# <AxesSubplot:xlabel='G1', ylabel='G2'>

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data = df,x = 'G2',y = 'G3',hue ='sex')
# Out:
# <AxesSubplot:xlabel='G2', ylabel='G3'>

# %%
col = []
for k in df.columns:
    if df[k].dtype == 'int64' or  df[k].dtype == 'float':
        col.append(k)
for j in col:
    print("column:",j)
    plt.boxplot(df[j])
    plt.show()
# Out:
# column: age
# column: studytime
# column: failures
# column: famrel
# column: freetime
# column: goout
# column: Dalc
# column: Walc
# column: health
# column: absences
# column: G1
# column: G2
# column: G3

# %%
df1  = pd.get_dummies(df, drop_first =True)
df1
# Out:
#       age  studytime  failures  famrel  freetime  goout  Dalc  Walc  health  \
# 0      18          2         0       4         3      4     1     1       3
# 1      17          2         0       5         3      3     1     1       3
# 2      15          2         3       4         3      2     2     3       3
# 3      15          3         0       3         2      2     1     1       5
# 4      16          2         0       4         3      2     1     2       5
# ...   ...        ...       ...     ...       ...    ...   ...   ...     ...
# 1039   19          3         1       5         4      2     1     2       5
# 1040   18          2         0       4         3      4     1     1       1
# 1041   18          2         0       1         1      1     1     1       5
# 1042   17          1         0       2         4      5     3     4       2
# 1043   18          1         0       4         4      1     3     4       5
#
# ...

# %% [markdown]
# #### Creating Feature Set(X) and Outcome Variable(Y)

# %%
x = df1.drop('G3', axis=1)
y = df1['G3']

# %%
x.shape
# Out:
# (1044, 22)

# %%
import numpy as np
y=np.array(y)
y.shape
# Out:
# (1044,)

# %% [markdown]
# #### standardizing the data

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# Fit the scaler on the training data and transform both training and test data
x_sc = sc.fit_transform(x)
x_sc
# Out:
# array([[ 1.02788947,  0.03560569, -0.40310574, ..., -0.51671103,
#         -0.98857105, -0.74247088],
#        [ 0.22103488,  0.03560569, -0.40310574, ..., -0.51671103,
#         -0.98857105, -0.74247088],
#        [-1.3926743 ,  0.03560569,  4.17126813, ...,  1.93531769,
#         -0.98857105, -0.74247088],
#        ...,
#        [ 1.02788947,  0.03560569, -0.40310574, ..., -0.51671103,
#          1.01156108, -0.74247088],
#        [ 0.22103488, -1.16350193, -0.40310574, ..., -0.51671103,
#         -0.98857105, -0.74247088],
#        [ 1.02788947, -1.16350193, -0.40310574, ..., -0.51671103,
#         -0.98857105, -0.74247088]])

# %% [markdown]
# #### Split Training and Testing Data

# %%
from sklearn.model_selection import train_test_split

train_x,test_x,train_y,test_y = train_test_split(x,y, train_size = 0.8, random_state=42)
train_x.shape, test_x.shape
# Out:
# ((835, 22), (209, 22))

# %% [markdown]
# ### Model Training & Testing

# %% [markdown]
# #### 1. Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
lrm = regression.fit(train_x, train_y)

# %%
#Predict Y

y_pred = lrm.predict(test_x)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
lrm_mae = mean_absolute_error(test_y, y_pred)
print("Mean absolute Error:", np.sqrt(lrm_mae))
# Out:
# Mean absolute Error: 1.006430268017171

# %%
lrm_mse = mean_squared_error(test_y, y_pred)
print("Mean Squared Error:", np.sqrt(lrm_mse))
# Out:
# Mean Squared Error: 1.758686607253946

# %%
lrm_r2_score = r2_score(test_y, y_pred)
print("The accuracy of our model is {}%".format(round(lrm_r2_score, 2) *100))
# Out:
# The accuracy of our model is 80.0%

# %% [markdown]
# #### 2. Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

randomforest = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
random_forest_model = randomforest.fit(train_x,train_y)

# %%
#predict y

rf_y_pred = random_forest_model.predict(test_x)
rf_y_pred
# Out:
# array([10.79      ,  7.39      , 13.38      , 11.16      , 12.66      ,
#        12.08      ,  2.86      , 10.91      , 14.4       , 13.26      ,
#        15.53      ,  4.7       ,  8.02      , 10.74      ,  8.38      ,
#        12.06      ,  9.69      , 15.78      , 11.08      , 12.51      ,
#        10.08      , 15.9       , 10.92      ,  1.27      , 15.8875    ,
#        11.4       , 17.72      , 16.36      , 10.71      ,  9.6       ,
#        10.3       ,  9.67      , 17.9       , 11.02      , 15.225     ,
#        14.84      , 15.66      , 18.48      ,  9.45      , 13.51      ,
#        15.07833333, 16.69      , 10.75      ,  8.58      , 15.95      ,
#        10.21      , 11.1       , 16.32857143, 12.29      , 11.07      ,
#        11.54      , 15.13833333, 10.2       , 10.16      ,  7.66      ,
#        10.83      , 10.96      , 13.37      , 17.37      ,  7.66      ,
#        11.77      ,  5.27      ,  7.88      , 12.22      ,  8.15      ,
# ...

# %%
mae = mean_absolute_error(test_y, rf_y_pred)
print("Mean absolute Error:", np.sqrt(mae))
# Out:
# Mean absolute Error: 0.9914096166694203

# %%
mse = mean_squared_error(test_y, rf_y_pred)
print("Mean Squared Error:", np.sqrt(mse))
# Out:
# Mean Squared Error: 1.710872149760753

# %%
r_squared = r2_score(test_y, rf_y_pred)
print("The accuracy of our model is {}%".format(round(r_squared, 2) *100))
# Out:
# The accuracy of our model is 81.0%

# %% [markdown]
# #### 3. Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

decisiontree = DecisionTreeRegressor(criterion = 'squared_error', min_samples_split=20, max_depth=5)
dt= decisiontree.fit(train_x,train_y)

# %%
#predict y

dt_pred_y = dt.predict(test_x)
dt_pred_y
# Out:
# array([10.01298701,  8.35897436, 13.18681319, 11.13333333, 12.65151515,
#        12.04651163,  3.3125    , 11.13333333, 14.39130435, 13.18681319,
#        15.33333333,  3.3125    ,  7.69230769, 10.79310345,  8.35897436,
#        12.04651163,  8.25      , 16.29166667, 11.13333333, 12.04651163,
#         9.46052632, 15.75      , 11.13333333,  0.        , 15.33333333,
#        11.13333333, 17.35      , 16.29166667, 11.13333333,  8.25      ,
#        10.01298701, 10.01298701, 18.44444444, 11.13333333, 15.33333333,
#        14.44444444, 15.33333333, 18.44444444, 10.01298701, 13.18681319,
#        15.33333333, 15.        , 11.13333333,  8.25      , 17.        ,
#        10.01298701, 11.13333333, 16.29166667, 12.04651163, 11.13333333,
#        11.13333333, 15.33333333, 10.79310345, 10.01298701,  7.69230769,
#        11.13333333, 11.13333333, 13.18681319, 17.35      ,  8.35897436,
#        12.04651163,  8.25      ,  7.69230769, 12.04651163,  7.69230769,
# ...

# %%
mae = mean_absolute_error(test_y, dt_pred_y)
print("Mean absolute Error:", np.sqrt(mae))
# Out:
# Mean absolute Error: 0.9823840513875268

# %%
mse = mean_squared_error(test_y, dt_pred_y)
print("Mean Squared Error:", np.sqrt(mse))
# Out:
# Mean Squared Error: 1.7331557720902075

# %%
r_squared = r2_score(test_y, dt_pred_y)
print("The accuracy of our model is {}%".format(round(r_squared, 2) *100))
# Out:
# The accuracy of our model is 81.0%

# %% [markdown]
# #### 4.XGBoost

# %%
from xgboost import XGBRegressor

# %%
xgbregressor = XGBRegressor(n_estimators=1000, max_depth=7, eta=0.1, subsample=0.7, colsample_bytree=0.8)
xgb = xgbregressor.fit(train_x,train_y)

# %%
#predict y

xgb_pred_y = xgb.predict(test_x)
xgb_pred_y
# Out:
# array([10.411001  ,  5.714772  , 14.040079  , 11.105714  , 12.808971  ,
#        12.462888  ,  3.1810477 , 10.933588  , 15.120044  , 13.454422  ,
#        16.986002  ,  6.923494  ,  7.766248  , 10.627638  ,  8.817861  ,
#        12.234096  ,  7.728314  , 15.960575  , 11.075838  , 13.17514   ,
#        10.228443  , 16.038944  , 11.449032  ,  0.49369553, 15.758562  ,
#        11.597616  , 17.246428  , 15.959943  , 10.612239  ,  9.322021  ,
#        10.352163  ,  9.6896515 , 17.92417   , 10.981603  , 15.366072  ,
#        14.571102  , 15.34349   , 17.91888   ,  8.780635  , 13.451536  ,
#        15.022355  , 16.86525   , 11.026     ,  8.941786  , 15.115413  ,
#        11.53414   , 11.01538   , 16.389269  , 13.627324  , 11.294168  ,
#        11.145224  , 15.277322  , 10.469138  ,  9.729056  ,  7.670446  ,
#        10.478025  , 11.207176  , 13.6436615 , 17.202763  ,  7.72086   ,
#         5.964807  ,  6.9034805 ,  7.654793  , 11.178201  ,  7.707986  ,
# ...

# %%
mae = mean_absolute_error(test_y, xgb_pred_y)
print("Mean absolute Error:", np.sqrt(mae))
# Out:
# Mean absolute Error: 1.0462345134158122

# %%
mse = mean_squared_error(test_y, xgb_pred_y)
print("Mean Squared Error:", np.sqrt(mse))
# Out:
# Mean Squared Error: 1.7777708149698497

# %%
r_squared = r2_score(test_y, xgb_pred_y)
print("The accuracy of our model is {}%".format(round(r_squared, 2) *100))
# Out:
# The accuracy of our model is 80.0%

# %% [markdown]
# #### 5. KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_df = KNeighborsRegressor(n_neighbors = 6 , metric = 'euclidean')

# %%
knn_model = knn_df.fit(train_x,train_y)

# %%
knn_y_pred = knn_model.predict(test_x)
knn_y_pred
# Out:
# array([10.5       ,  8.16666667, 14.        , 10.83333333, 12.66666667,
#        12.        ,  5.66666667, 11.16666667, 15.        , 13.        ,
#        15.16666667,  7.83333333,  9.        , 11.        ,  9.5       ,
#        12.33333333, 10.16666667, 16.5       , 11.16666667, 12.33333333,
#        10.        , 15.83333333, 11.16666667,  0.        , 16.33333333,
#        11.33333333, 16.16666667, 15.83333333, 10.66666667,  8.5       ,
#        10.16666667, 10.33333333, 17.83333333, 10.66666667, 15.16666667,
#        13.16666667, 14.        , 13.33333333,  8.5       , 13.16666667,
#        15.        , 16.66666667, 10.5       ,  8.        , 14.83333333,
#        10.33333333, 10.66666667, 15.83333333, 13.33333333, 12.16666667,
#        12.16666667, 15.5       , 10.83333333,  9.        ,  8.33333333,
#        11.16666667, 11.33333333, 13.        , 17.5       ,  8.66666667,
#        10.16666667, 10.33333333,  7.33333333, 11.83333333,  8.33333333,
# ...

# %%
mae = mean_absolute_error(test_y, knn_y_pred)
print("Mean absolute Error:", np.sqrt(mae))
# Out:
# Mean absolute Error: 1.0516941599441378

# %%
mse = mean_squared_error(test_y, knn_y_pred)
print("Root Mean Squared Error:", np.sqrt(mse))
# Out:
# Root Mean Squared Error: 1.8933204730340243

# %%
r_squared = r2_score(test_y, knn_y_pred)
print("The accuracy of our model is {}%".format(round(r_squared, 2) *100))
# Out:
# The accuracy of our model is 77.0%

# %% [markdown]
# #### 6. SVM

# %%
from sklearn.svm import SVR

svm_df  = SVR(kernel='linear', C = 0.1)

# %%
svm_model = svm_df.fit(train_x,train_y)

# %%
svm_y_pred = svm_model.predict(test_x)
svm_y_pred
# Out:
# array([10.13788075,  8.06640769, 13.17313571, 11.15805734, 12.10746867,
#        12.0355234 ,  6.07586485, 11.11140556, 14.14788116, 13.11758931,
#        15.16619855,  7.04751934,  7.16097216, 10.16884644,  8.14105668,
#        12.05089612,  9.03007935, 16.03220208, 11.15144607, 12.05150721,
#         9.18276325, 16.13114031, 11.12735232,  0.29090577, 15.19604913,
#        11.17921112, 17.10439559, 16.0959462 , 11.07392938,  9.16324553,
#        10.10335101, 10.03146464, 18.08627391, 10.97623525, 15.14205186,
#        14.07550134, 14.97691672, 18.08092199, 10.00717705, 13.14996252,
#        15.136157  , 17.03446108, 11.11716935,  9.08567798, 15.01997416,
#        10.11127625, 11.01952959, 16.10311546, 12.15151876, 11.14030025,
#        11.10903287, 15.14110101, 10.15273351, 10.10789473,  6.96651645,
#        11.05578251, 11.10950692, 13.16530389, 17.07968017,  7.98527652,
#        11.89266703,  8.14437613,  7.12185932, 12.12729611,  7.11369414,
# ...

# %%
mae = mean_absolute_error(test_y, svm_y_pred)
print("Mean absolute Error:", np.sqrt(mae))
# Out:
# Mean absolute Error: 0.9334425601567358

# %%
mse = mean_squared_error(test_y, svm_y_pred)
print("Root Mean Squared Error:", np.sqrt(mse))
# Out:
# Root Mean Squared Error: 1.7355989508868042

# %%
r_squared = r2_score(test_y, svm_y_pred)
print("The accuracy of our model is {}%".format(round(r_squared, 2) *100))
# Out:
# The accuracy of our model is 81.0%
